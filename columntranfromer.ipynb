# %%
import pandas as pd 
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import  StandardScaler, OneHotEncoder

# %%
data=pd.DataFrame({
    'age':[25,30,23],
    'city':['delhi','mumbai','jaipur'],
    'salary':[50000,70000,45000]
})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     3 non-null      int64
#  1   city    3 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
#step2 define the column transformer

# %%
column_transformer=ColumnTransformer([
    ('num',StandardScaler(),['age','salary']),
    ('cat',OneHotEncoder(),['city'])
 ])

# %%
transformed_data=column_transformer.fit_transform(data)

# %%
transformed_df = pd.DataFrame(transformed_data, columns=['age_scaled', 'salary_scaled', 'city_LA', 'city_NY', 'city_SF'])

# %%
print(transformed_df)
# Out:
#    age_scaled  salary_scaled  city_LA  city_NY  city_SF
# 0   -0.339683       -0.46291      1.0      0.0      0.0
# 1    1.358732        1.38873      0.0      0.0      1.0
# 2   -1.019049       -0.92582      0.0      1.0      0.0
