# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\91994\Desktop\ny\placement (1).csv")

# %%
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 754  7.91                  17.0       0
# 19   7.63                  29.0       0
# 282  6.43                  44.0       1
# 469  5.86                  46.0       1
# 689  8.02                  67.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.displot(df['cgpa'])
plt.subplot(1,2,2)
sns.displot(df['placement_exam_marks'])
plt.show()

# %%
print("mean vlaue of vgpa",df['cgpa'].mean())
print("std vlaue of vgpa",df['cgpa'].std())
print("min vlaue of vgpa",df['cgpa'].min())
print("max vlaue of vgpa",df['cgpa'].max())
# Out:
# mean vlaue of vgpa 6.96124
# std vlaue of vgpa 0.6158978751323894
# min vlaue of vgpa 4.89
# max vlaue of vgpa 9.12

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.808933625397168
# Lowest allowed 5.113546374602832

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
#trimming
new_df=df[(df['cgpa']<8.80)&(df['cgpa']>5.11)]
new_df
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 991  7.04                  57.0       0
# 992  6.26                  12.0       0
# 993  6.73                  21.0       1
# 994  6.48                  63.0       0
# 998  8.62                  46.0       1
#
# [995 rows x 3 columns]
